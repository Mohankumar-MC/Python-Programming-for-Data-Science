# %% [markdown]
# Given a list of n lists, write a function which returns the intersection of all the n lists. Each list can have any number of elements.
#
# Example 1:
#
# ```
# input = [[5, 5, 5, 8, 10],
#       [5, 5, 7, 8],
#       [5, 5, 8, 9, 11]]
# ```
#
# ```
# output = [5, 5, 8]
# ```
# Example 2:
#
# ```
# input = [[5, 6],
#       [5, 5, 7, 8],
#       [5, 5, 8, 9]]
# ```
#
#
# ```
# output = [5]
# ```

# %%
input1 = [[5, 5, 5, 8, 10], [5, 5, 7, 8], [5, 5, 8, 9, 11]]
input2 = [[5, 6], [5, 5, 7, 8], [5, 5, 8, 9]]

# %%
def get_min_len_list(input):

  '''
  This function takes list of list and returns list with minimun number of elements
  '''
  min_len = len(input[0])
  min_len_list = input[0]

  for list_ in input:
    if len(list_) < min_len:
      min_len = len(list_)
      min_len_list = list_

  return min_len_list

# %%
def get_frequency_map(min_len_list):
  '''
  This function creats frequency map for a ginen list
  '''
  frequency_map = {}
  for ele in min_len_list:
    if ele in frequency_map.keys():
      frequency_map[ele] = frequency_map[ele] + 1
    else:
      frequency_map[ele] = 1
  return frequency_map

# %%
def create_list_from_frequency_map(frequency_map):

  '''
  This finction creats list from frequency maps
  '''
  final_list = []
  for kay, value in frequency_map.items():
    for i in range(value):
      final_list.append(kay)
  return final_list

# %%
def get_intersecton(list_):
  min_len_list = get_min_len_list(list_)
  min_len_list_frequency_map = get_frequency_map(min_len_list)

  for key,value in min_len_list_frequency_map.items():

    for list_ in input:
      if value > list_.count(key):
        min_len_list_frequency_map[key] = list_.count(key)

  final_result = create_list_from_frequency_map(min_len_list_frequency_map)

  return final_result

# %%
print(get_intersecton(input1))
print(get_intersecton(input2))
# Out:
# [5, 5, 8]
# [5]
